# %% [markdown]
# # Import thư viện

# %%
from bs4 import BeautifulSoup
import requests
import json
import csv

# %% [markdown]
# # Util

# %% [markdown]
# ### Write Json to .json

# %%
def writeJsonToFile(html):
    with open('out.json', 'w') as f:
        return json.dump(html, f)

# %% [markdown]
# ### Write records to .csv

# %%
def add_dict_to_csv(dict):
    # Mở file CSV trong chế độ ghi
    with open("/content/drive/MyDrive/KHDL/data_train.csv", mode="a", newline="", encoding="utf-8") as file:
        # Tạo writer object
        writer = csv.writer(file)
        # Ghi data row
        writer.writerow(dict)

# %% [markdown]
# ### Convert Timestamp to year

# %%
import datetime
def convert_timestamp_to_year(timestamp):
    seconds = abs(timestamp) // 1000
    formatted_year = None
    try:
        delta = datetime.timedelta(seconds=seconds)
        epoch = datetime.datetime(1970, 1, 1)
        if timestamp < 0:
            date = epoch - delta
        else:
            date = epoch + delta
        formatted_year = date.strftime("%Y")
        return formatted_year
    except Exception as e:
        return None

# %% [markdown]
# # I.    CRAWL DATA

# %%
book_dict_origin = {
    'title':None, #tiêu đề sách
    'author':None, #tác giả
    'language':None, #ngôn ngữ của sách
    'avg_ratings':None, # điểm đánh giá
    'ratings_count':None, # số lượng ratings
    'reviews_count':None, # số lượng reviews
    'publisher':None, # nhà/người phát hành
    'publish_year':None, # Năm phát hành
    'num_pages':None, # số trang
    'page_format':None, # loại bìa
    'genres':None, # Thể loại
    'link':None # link sách
}

# %%
def get_soup(bookURL):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Chrome/4.0.209.0 Safari/532.0'}
    status = None
    response = None
    while(status != 200):
        try:
            response = requests.get(bookURL, headers=headers)
            status = response.status_code
        except Exception as e:
            print(e)
    html_content = response.content
    soup = BeautifulSoup(html_content, 'html.parser')
    return soup

# %%
def get_book_details_dict(soup):
    book_dict = book_dict_origin
    
    # Title
    title = soup.find('h1', {'class':'Text__title1'}).text
    book_dict['title'] = title

    # Author
    author = soup.find('span', {'class':'ContributorLink__name'}).text
    book_dict['author'] = author

    # Voters-count
    ratings_count = soup.find('span', {'data-testid':'ratingsCount'}).text.split()[0]
    book_dict['ratings_count'] = ratings_count

    # Rating
    avg_ratings = soup.find('div', {'class':'RatingStatistics__rating'}).text
    book_dict['avg_ratings'] = avg_ratings

    # Reviews-count
    reviews_count = soup.find('span', {'data-testid':'reviewsCount'}).text.split()[0]
    book_dict['reviews_count'] = reviews_count

    # Raw details
    script_tag_book_details_raw = soup.find('script', {'type': 'application/json'}).get_text()
    script_tag_book_details = json.loads(script_tag_book_details_raw)['props']['pageProps']['apolloState']
    # writeJsonToFile(json.loads(script_tag_book_details_raw))
    book_details_wrap = next(iter({key: val for key, val in script_tag_book_details.items() if "Book:" in key and "details" in val}.values()))
    book_details = book_details_wrap['details']
    # Publisher
    publisher = book_details['publisher']   
    book_dict['publisher'] = publisher

    # Language
    language = book_details['language']['name']
    book_dict['language'] = language

    # published
    timestamp = book_details['publicationTime']# millisecond
    formatted_year = None
    if(timestamp):
        formatted_year = convert_timestamp_to_year(timestamp)
        book_dict['publish_year'] = formatted_year
    else:
        book_dict['publish_year'] = formatted_year
    

    # Pages-count
    num_pages = book_details['numPages']
    book_dict['num_pages'] = num_pages

    # Pages-count
    page_format = book_details['format']
    book_dict['page_format'] = page_format

    #Genres
    genres = book_details_wrap['bookGenres']
    genresList = []
    if(genres):
      if(len(genres)>0):
          for item in genres:
              genresList.append(item['genre']['name'])
          book_dict['genres'] = genresList
    return book_dict

# %%
try:
    rootURL = 'https://www.goodreads.com'

    # create csv header ()
    add_dict_to_csv(book_dict_origin.keys())

    #  crawl and save to csv
    count = 0
    for i in range(1,101):
        # list book of page i
        ListBookURL = f'https://www.goodreads.com/list/show/1.Best_Books_Ever?page={i}'
        # get soup
        listBook_soup = None
        while(True):
            listBook_soup = get_soup(ListBookURL)
            # check get list book
            if(books := listBook_soup.find_all('a', {'class':'bookTitle'})):
                break
            
        books = listBook_soup.find_all('a', {'class':'bookTitle'})
        # link of book
        for book in books:
            # get link
            bookURL = rootURL+book['href']
            
            print("fetching data...",bookURL)
            # get soup
            bookSoup = None
            while(True):
                bookSoup = bookSoup = get_soup(bookURL)
                if(bookSoup.find('h1', {'class':'Text__title1'})):
                    break

            # get detais
            bookDetails = get_book_details_dict(bookSoup)
            bookDetails['link'] = bookURL
            print(bookDetails)
            
            # save to csv
            add_dict_to_csv(bookDetails.values())
            count = count + 1

            # show 
            print("crawled and saved")
            print()
except Exception as e:
    print("Error:", e)
    raise e
# Out:
# fetching data... https://www.goodreads.com/book/show/72308.Dalva
# {'title': 'Dalva', 'author': 'Jim Harrison', 'language': 'English', 'avg_ratings': '4.18', 'ratings_count': '3,811', 'reviews_count': '323', 'publisher': 'Washington Square Press', 'publish_year': '1991', 'num_pages': 324, 'page_format': 'Paperback', 'genres': ['Fiction', 'Historical Fiction', 'Literary Fiction', 'Novels', 'The United States Of America', 'Westerns', 'Literature', 'Nature', 'Classics', 'Contemporary'], 'link': 'https://www.goodreads.com/book/show/72308.Dalva'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/7826117-jane
# {'title': 'Jane', 'author': 'April Lindner', 'language': 'English', 'avg_ratings': '3.59', 'ratings_count': '8,991', 'reviews_count': '1,733', 'publisher': 'Poppy', 'publish_year': '2010', 'num_pages': 373, 'page_format': 'Hardcover', 'genres': ['Young Adult', 'Romance', 'Retellings', 'Fiction', 'Contemporary', 'Teen', 'Realistic Fiction', 'Classics', 'Chick Lit', 'Mystery'], 'link': 'https://www.goodreads.com/book/show/7826117-jane'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/9766078-the-map-of-time
# {'title': 'The Map of Time', 'author': 'Félix J. Palma', 'language': 'English', 'avg_ratings': '3.39', 'ratings_count': '12,509', 'reviews_count': '2,394', 'publisher': 'Atria Books', 'publish_year': '2011', 'num_pages': 613, 'page_format': 'Hardcover', 'genres': ['Fantasy', 'Historical Fiction', 'Steampunk', 'Fiction', 'Science Fiction', 'Time Travel', 'Mystery', 'Historical', 'Adult', 'Science Fiction Fantasy'], 'link': 'https://www.goodreads.com/book/show/9766078-the-map-of-time'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/815786.Empress
# {'title': 'Empress', 'author': 'Shan Sa', 'language': 'English', 'avg_ratings': '3.69', 'ratings_count': '6,115', 'reviews_count': '496', 'publisher': 'Harper', 'publish_year': '2006', 'num_pages': 336, 'page_format': 'Hardcover', 'genres': ['Historical Fiction', 'China', 'Fiction', 'Historical', 'Asia', 'Asian Literature', 'Cultural', 'Womens', 'Adult Fiction', 'France'], 'link': 'https://www.goodreads.com/book/show/815786.Empress'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/13645330-syrian-folktales
# {'title': 'Syrian Folktales', 'author': 'Muna Imady', 'language': 'English', 'avg_ratings': '4.52', 'ratings_count': '93', 'reviews_count': '41', 'publisher': 'MSI Press', 'publish_year': '2012', 'num_pages': 126, 'page_format': 'Paperback', 'genres': ['Mythology'], 'link': 'https://www.goodreads.com/book/show/13645330-syrian-folktales'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/9462775-the-last-little-blue-envelope
# {'title': 'The Last Little Blue Envelope', 'author': 'Maureen Johnson', 'language': 'English', 'avg_ratings': '3.84', 'ratings_count': '24,236', 'reviews_count': '1,764', 'publisher': 'HarperTeen', 'publish_year': '2011', 'num_pages': 282, 'page_format': 'Hardcover', 'genres': ['Young Adult', 'Romance', 'Contemporary', 'Fiction', 'Travel', 'Chick Lit', 'Realistic Fiction', 'Teen', 'Adventure', 'Young Adult Contemporary'], 'link': 'https://www.goodreads.com/book/show/9462775-the-last-little-blue-envelope'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/20522640-mortal-heart
# {'title': 'Mortal Heart', 'author': 'Robin LaFevers', 'language': 'English', 'avg_ratings': '4.10', 'ratings_count': '24,130', 'reviews_count': '2,696', 'publisher': 'HMH Books for Young Readers', 'publish_year': '2014', 'num_pages': 444, 'page_format': 'Hardcover', 'genres': ['Fantasy', 'Young Adult', 'Historical Fiction', 'Romance', 'Historical', 'Fiction', 'Young Adult Fantasy', 'Adventure', 'Mythology', 'Paranormal'], 'link': 'https://www.goodreads.com/book/show/20522640-mortal-heart'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/1470282.Les_Enfants_de_la_libert_
# {'title': 'Les Enfants de la liberté', 'author': 'Marc Levy', 'language': 'French', 'avg_ratings': '3.99', 'ratings_count': '3,410', 'reviews_count': '211', 'publisher': 'Laffont', 'publish_year': '2007', 'num_pages': 433, 'page_format': 'Paperback', 'genres': ['France', 'Fiction', 'Historical Fiction', 'Roman', 'Romance', 'Historical', 'War', 'Contemporary', 'World War II', 'French Literature'], 'link': 'https://www.goodreads.com/book/show/1470282.Les_Enfants_de_la_libert_'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/147635.Holy_Bible
# {'title': 'Holy Bible: Revised Standard Version', 'author': 'Anonymous', 'language': 'English', 'avg_ratings': '4.46', 'ratings_count': '2,047', 'reviews_count': '116', 'publisher': '', 'publish_year': '1972', 'num_pages': 1255, 'page_format': None, 'genres': ['Religion', 'Christianity', 'Christian', 'Reference', 'Nonfiction', 'Classics', 'Theology', 'Catholic', 'Spirituality', 'History'], 'link': 'https://www.goodreads.com/book/show/147635.Holy_Bible'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/17729036-elite
# {'title': 'Elite', 'author': 'Rachel Van Dyken', 'language': 'English', 'avg_ratings': '3.98', 'ratings_count': '21,703', 'reviews_count': '1,948', 'publisher': 'Rachel Van Dyken', 'publish_year': '2013', 'num_pages': 322, 'page_format': 'Kindle Edition', 'genres': ['Romance', 'New Adult', 'College', 'Contemporary', 'Young Adult', 'Contemporary Romance', 'Mystery', 'Crime', 'High School', 'Suspense'], 'link': 'https://www.goodreads.com/book/show/17729036-elite'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/6604887
# {'title': 'أنت لي', 'author': 'منى المرشود', 'language': 'Arabic', 'avg_ratings': '3.88', 'ratings_count': '23,917', 'reviews_count': '2,893', 'publisher': 'أطياف للنشر والتوزيع - القطيف', 'publish_year': '2007', 'num_pages': 1607, 'page_format': 'Paperback', 'genres': ['Novels', 'Romance', 'Fiction', 'Unfinished', 'Romantic', 'Literature', 'Love', 'Drama', 'Realistic Fiction', 'War'], 'link': 'https://www.goodreads.com/book/show/6604887'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/513275.Jakob_von_Gunten
# {'title': 'Jakob von Gunten', 'author': 'Robert Walser', 'language': 'English', 'avg_ratings': '3.91', 'ratings_count': '4,940', 'reviews_count': '530', 'publisher': 'New York Review Books Classics', 'publish_year': '1999', 'num_pages': 176, 'page_format': 'Paperback', 'genres': ['Fiction', 'German Literature', 'Classics', 'Literature', 'Novels', 'Germany', '20th Century', 'Literary Fiction', 'Short Stories', 'European Literature'], 'link': 'https://www.goodreads.com/book/show/513275.Jakob_von_Gunten'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/982572.Do_a_B_rbara
# {'title': 'Doña Bárbara', 'author': 'Rómulo Gallegos', 'language': 'Spanish; Castilian', 'avg_ratings': '3.79', 'ratings_count': '4,871', 'reviews_count': '420', 'publisher': 'Cátedra', 'publish_year': '2005', 'num_pages': 480, 'page_format': 'Paperback', 'genres': ['Fiction', 'Classics', 'Spanish Literature', 'Historical Fiction', 'Magical Realism', 'Latin American Literature', 'Latin American', 'Romance', 'Novels', 'Literature'], 'link': 'https://www.goodreads.com/book/show/982572.Do_a_B_rbara'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/31549906-do-not-say-we-have-nothing
# {'title': 'Do Not Say We Have Nothing', 'author': 'Madeleine Thien', 'language': 'English', 'avg_ratings': '3.92', 'ratings_count': '21,261', 'reviews_count': '3,038', 'publisher': 'W. W. Norton & Company', 'publish_year': '2016', 'num_pages': 474, 'page_format': 'Hardcover', 'genres': ['Fiction', 'Historical Fiction', 'China', 'Canada', 'Historical', 'Asia', 'Literary Fiction', 'Contemporary', 'Music', 'Novels'], 'link': 'https://www.goodreads.com/book/show/31549906-do-not-say-we-have-nothing'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/40940205-tribe
# {'title': 'Tribe: On Homecoming and Belonging', 'author': 'Sebastian Junger', 'language': 'English', 'avg_ratings': '4.02', 'ratings_count': '41,463', 'reviews_count': '4,050', 'publisher': 'Twelve', 'publish_year': '2016', 'num_pages': 182, 'page_format': 'Kindle Edition', 'genres': ['Nonfiction', 'Psychology', 'History', 'Sociology', 'War', 'Philosophy', 'Audiobook', 'Military Fiction', 'Anthropology', 'Politics'], 'link': 'https://www.goodreads.com/book/show/40940205-tribe'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/230877.The_Holy_War
# {'title': 'The Holy War', 'author': 'John Bunyan', 'language': None, 'avg_ratings': '4.12', 'ratings_count': '1,288', 'reviews_count': '155', 'publisher': 'Whitaker House', 'publish_year': '2001', 'num_pages': 336, 'page_format': 'Paperback', 'genres': ['Christian', 'Fiction', 'Classics', 'Theology', 'Christian Fiction', 'Religion', 'Christianity', 'Fantasy', 'Christian Living', 'Literature'], 'link': 'https://www.goodreads.com/book/show/230877.The_Holy_War'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/8466114-in-the-name-of-revenge
# {'title': 'In the Name of Revenge', 'author': 'Starr Gardinier', 'language': None, 'avg_ratings': '4.33', 'ratings_count': '18', 'reviews_count': '8', 'publisher': None, 'publish_year': None, 'num_pages': None, 'page_format': 'ebook', 'genres': ['Christian', 'Fiction', 'Classics', 'Theology', 'Christian Fiction', 'Religion', 'Christianity', 'Fantasy', 'Christian Living', 'Literature'], 'link': 'https://www.goodreads.com/book/show/8466114-in-the-name-of-revenge'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/33813.Gold_Coast
# {'title': 'Gold Coast', 'author': 'Nelson DeMille', 'language': 'English', 'avg_ratings': '4.10', 'ratings_count': '28,431', 'reviews_count': '1,567', 'publisher': 'Time Warner Books UK', 'publish_year': '2001', 'num_pages': 637, 'page_format': 'Paperback', 'genres': ['Fiction', 'Thriller', 'Mystery', 'Mystery Thriller', 'Suspense', 'Crime', 'Audiobook', 'Novels', 'Contemporary', 'Adventure'], 'link': 'https://www.goodreads.com/book/show/33813.Gold_Coast'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/84076.Remember_Me
# {'title': 'Remember Me', 'author': 'Christopher Pike', 'language': 'English', 'avg_ratings': '4.04', 'ratings_count': '12,212', 'reviews_count': '737', 'publisher': "Hodder Children's Books", 'publish_year': '2003', 'num_pages': 272, 'page_format': 'Paperback', 'genres': ['Young Adult', 'Horror', 'Fiction', 'Mystery', 'Paranormal', 'Fantasy', 'Thriller', 'Ghosts', 'Supernatural', 'Childrens'], 'link': 'https://www.goodreads.com/book/show/84076.Remember_Me'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/114130.Honest_Illusions
# {'title': 'Honest Illusions', 'author': 'Nora Roberts', 'language': 'English', 'avg_ratings': '4.04', 'ratings_count': '16,300', 'reviews_count': '572', 'publisher': 'Berkley Trade', 'publish_year': '2002', 'num_pages': 432, 'page_format': 'Trade Paperback', 'genres': ['Romance', 'Contemporary Romance', 'Romantic Suspense', 'Contemporary', 'Fiction', 'Mystery', 'Suspense', 'Chick Lit', 'Adult', 'Audiobook'], 'link': 'https://www.goodreads.com/book/show/114130.Honest_Illusions'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/5776788-sandman-slim
# {'title': 'Sandman Slim', 'author': 'Richard Kadrey', 'language': 'English', 'avg_ratings': '3.94', 'ratings_count': '35,498', 'reviews_count': '3,162', 'publisher': 'Harper Voyager', 'publish_year': '2009', 'num_pages': 388, 'page_format': 'Hardcover', 'genres': ['Urban Fantasy', 'Fantasy', 'Horror', 'Fiction', 'Paranormal', 'Supernatural', 'Mystery', 'Magic', 'Demons', 'Noir'], 'link': 'https://www.goodreads.com/book/show/5776788-sandman-slim'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/7194943-vanished
# {'title': 'Vanished: When Lightning Strikes / Code Name Cassandra', 'author': 'Meg Cabot', 'language': 'English', 'avg_ratings': '4.19', 'ratings_count': '4,802', 'reviews_count': '248', 'publisher': 'Simon Pulse', 'publish_year': '2010', 'num_pages': 540, 'page_format': 'Paperback', 'genres': ['Young Adult', 'Paranormal', 'Fantasy', 'Mystery', 'Romance', 'Supernatural', 'Fiction', 'Teen', 'Science Fiction', 'Contemporary'], 'link': 'https://www.goodreads.com/book/show/7194943-vanished'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/8192675-fruits-basket
# {'title': 'Fruits Basket: The Complete Collection', 'author': 'Natsuki Takaya', 'language': 'English', 'avg_ratings': '4.58', 'ratings_count': '2,794', 'reviews_count': '163', 'publisher': 'Madman Entertainment', 'publish_year': '2009', 'num_pages': 4522, 'page_format': 'Paperback', 'genres': ['Manga', 'Graphic Novels', 'Fantasy', 'Romance', 'Comics', 'Young Adult', 'Fiction', 'Comics Manga', 'Anime', 'Childrens'], 'link': 'https://www.goodreads.com/book/show/8192675-fruits-basket'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/462024.Los_rboles_mueren_de_pie
# {'title': 'Los árboles mueren de pie', 'author': 'Alejandro Casona', 'language': 'Spanish; Castilian', 'avg_ratings': '4.14', 'ratings_count': '4,486', 'reviews_count': '328', 'publisher': 'Oceano De Mexico', 'publish_year': '2003', 'num_pages': 136, 'page_format': 'Mass Market Paperback', 'genres': ['Plays', 'Classics', 'School', 'Spanish Literature', 'Fiction', 'Theatre', 'Drama', 'Romance', 'Read For School', 'Literature'], 'link': 'https://www.goodreads.com/book/show/462024.Los_rboles_mueren_de_pie'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/11265560-the-mysterious-benedict-society
# {'title': "The Mysterious Benedict Society: Mr. Benedict's Book of Perplexing Puzzles, Elusive Enigmas, and Curious Conundrums", 'author': 'Trenton Lee Stewart', 'language': 'English', 'avg_ratings': '4.23', 'ratings_count': '2,947', 'reviews_count': '129', 'publisher': 'Megan Tingley Books', 'publish_year': '2011', 'num_pages': 176, 'page_format': 'Hardcover', 'genres': ['Fiction', 'Middle Grade', 'Childrens', 'Mystery', 'Young Adult', 'Puzzles', 'Adventure', 'Fantasy', 'Young Readers', 'Realistic Fiction'], 'link': 'https://www.goodreads.com/book/show/11265560-the-mysterious-benedict-society'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/63040.The_Last_Day_of_a_Condemned_Man
# {'title': 'The Last Day of a Condemned Man', 'author': 'Victor Hugo', 'language': 'English', 'avg_ratings': '4.00', 'ratings_count': '25,757', 'reviews_count': '1,792', 'publisher': 'Hesperus Press', 'publish_year': '2002', 'num_pages': 109, 'page_format': 'Paperback', 'genres': ['Classics', 'Fiction', 'France', 'French Literature', '19th Century', 'Historical Fiction', 'Novels', 'Literature', 'Roman', 'School'], 'link': 'https://www.goodreads.com/book/show/63040.The_Last_Day_of_a_Condemned_Man'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/323455.De_Profundis
# {'title': 'De Profundis', 'author': 'Oscar Wilde', 'language': 'Spanish; Castilian', 'avg_ratings': '4.21', 'ratings_count': '17,620', 'reviews_count': '1,703', 'publisher': 'Fontamara', 'publish_year': '1993', 'num_pages': 188, 'page_format': 'Paperback', 'genres': ['Classics', 'Nonfiction', 'LGBT', 'Biography', 'Philosophy', 'Memoir', 'Literature', 'Essays', 'Queer', '19th Century'], 'link': 'https://www.goodreads.com/book/show/323455.De_Profundis'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/67243.Dear_Enemy
# {'title': 'Dear Enemy', 'author': 'Jean Webster', 'language': 'English', 'avg_ratings': '3.93', 'ratings_count': '10,789', 'reviews_count': '1,437', 'publisher': 'IndyPublish', 'publish_year': '2006', 'num_pages': 350, 'page_format': 'Paperback', 'genres': ['Classics', 'Fiction', 'Romance', 'Young Adult', 'Historical Fiction', 'Novels', 'Historical', 'Childrens', 'Humor', 'American'], 'link': 'https://www.goodreads.com/book/show/67243.Dear_Enemy'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/17859911-craving-constellations
# {'title': 'Craving Constellations', 'author': 'Nicole Jacquelyn', 'language': 'English', 'avg_ratings': '3.99', 'ratings_count': '19,649', 'reviews_count': '1,277', 'publisher': '', 'publish_year': '2013', 'num_pages': 305, 'page_format': 'Kindle Edition', 'genres': ['Romance', 'Contemporary Romance', 'Contemporary', 'Abuse', 'Erotica', 'Adult', 'Dark', 'New Adult', 'Motorcycle', 'Erotic Romance'], 'link': 'https://www.goodreads.com/book/show/17859911-craving-constellations'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/11431896-the-bitter-kingdom
# {'title': 'The Bitter Kingdom', 'author': 'Rae Carson', 'language': 'English', 'avg_ratings': '4.20', 'ratings_count': '36,403', 'reviews_count': '2,914', 'publisher': 'Greenwillow Books', 'publish_year': '2013', 'num_pages': 433, 'page_format': 'Hardcover', 'genres': ['Fantasy', 'Young Adult', 'Young Adult Fantasy', 'Fiction', 'Romance', 'Teen', 'Magic', 'High Fantasy', 'Adventure', 'Audiobook'], 'link': 'https://www.goodreads.com/book/show/11431896-the-bitter-kingdom'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/22428828-welcome-to-shadowhunter-academy
# {'title': 'Welcome to Shadowhunter Academy', 'author': 'Cassandra Clare', 'language': 'English', 'avg_ratings': '4.10', 'ratings_count': '23,631', 'reviews_count': '2,172', 'publisher': 'Margaret K. McElderry Books', 'publish_year': '2015', 'num_pages': 78, 'page_format': 'Kindle Edition', 'genres': ['Fantasy', 'Young Adult', 'Short Stories', 'Paranormal', 'Urban Fantasy', 'Novella', 'Fiction', 'Vampires', 'Magic', 'Young Adult Fantasy'], 'link': 'https://www.goodreads.com/book/show/22428828-welcome-to-shadowhunter-academy'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/526071.The_First_Chronicles_of_Druss_the_Legend
# {'title': 'The First Chronicles of Druss the Legend', 'author': 'David Gemmell', 'language': 'English', 'avg_ratings': '4.35', 'ratings_count': '11,573', 'reviews_count': '255', 'publisher': 'Del Rey', 'publish_year': '1999', 'num_pages': 334, 'page_format': 'Mass Market Paperback', 'genres': ['Fantasy', 'Fiction', 'Heroic Fantasy', 'Epic Fantasy', 'High Fantasy', 'Sword and Sorcery', 'Adventure', 'Science Fiction Fantasy', 'Epic', 'Novels'], 'link': 'https://www.goodreads.com/book/show/526071.The_First_Chronicles_of_Druss_the_Legend'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/16079583-the-shifter-dimension
# {'title': 'The Shifter Dimension', 'author': 'J.M. Johnson', 'language': 'English', 'avg_ratings': '4.58', 'ratings_count': '107', 'reviews_count': '11', 'publisher': 'Amazon Digital Services', 'publish_year': '2012', 'num_pages': 236, 'page_format': 'Kindle Edition', 'genres': ['Science Fiction', 'Military Science Fiction'], 'link': 'https://www.goodreads.com/book/show/16079583-the-shifter-dimension'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/17560541-don-t-even-think-about-it
# {'title': "Don't Even Think About It", 'author': 'Sarah Mlynowski', 'language': 'English', 'avg_ratings': '3.72', 'ratings_count': '7,225', 'reviews_count': '1,190', 'publisher': 'Delacorte Press', 'publish_year': '2014', 'num_pages': 317, 'page_format': 'Hardcover', 'genres': ['Young Adult', 'Contemporary', 'Paranormal', 'Fantasy', 'Romance', 'Fiction', 'Science Fiction', 'Teen', 'High School', 'Supernatural'], 'link': 'https://www.goodreads.com/book/show/17560541-don-t-even-think-about-it'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/20909906-dangerous-lies
# {'title': 'Dangerous Lies', 'author': 'Becca Fitzpatrick', 'language': None, 'avg_ratings': '3.81', 'ratings_count': '11,287', 'reviews_count': '1,341', 'publisher': 'Simon & Schuster', 'publish_year': '2015', 'num_pages': 400, 'page_format': 'Kindle Edition', 'genres': ['Young Adult', 'Romance', 'Mystery', 'Contemporary', 'Thriller', 'Fiction', 'Suspense', 'Crime', 'Mystery Thriller', 'Teen'], 'link': 'https://www.goodreads.com/book/show/20909906-dangerous-lies'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/31926533-penelope-gilbert-and-the-children-of-azure
# {'title': 'Penelope Gilbert and the Children of Azure', 'author': 'Emily A. Steward', 'language': 'English', 'avg_ratings': '4.35', 'ratings_count': '49', 'reviews_count': '22', 'publisher': 'Clean Reads', 'publish_year': '2016', 'num_pages': 250, 'page_format': 'Kindle Edition', 'genres': ['Middle Grade', 'Fantasy'], 'link': 'https://www.goodreads.com/book/show/31926533-penelope-gilbert-and-the-children-of-azure'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/26233572-i-see-you
# {'title': 'I See You', 'author': 'Clare Mackintosh', 'language': 'English', 'avg_ratings': '3.87', 'ratings_count': '71,228', 'reviews_count': '7,017', 'publisher': 'Sphere', 'publish_year': '2017', 'num_pages': 386, 'page_format': 'Kindle Edition', 'genres': ['Thriller', 'Mystery', 'Fiction', 'Mystery Thriller', 'Crime', 'Suspense', 'Psychological Thriller', 'Audiobook', 'Adult', 'Contemporary'], 'link': 'https://www.goodreads.com/book/show/26233572-i-see-you'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/30238163-ace-of-shades
# {'title': 'Ace of Shades', 'author': 'Amanda Foody', 'language': 'English', 'avg_ratings': '3.85', 'ratings_count': '17,854', 'reviews_count': '3,418', 'publisher': 'Harlequin Teen', 'publish_year': '2018', 'num_pages': 411, 'page_format': 'Hardcover', 'genres': ['Fantasy', 'Young Adult', 'Young Adult Fantasy', 'Romance', 'LGBT', 'Fiction', 'Mystery', 'Audiobook', 'Magic', 'High Fantasy'], 'link': 'https://www.goodreads.com/book/show/30238163-ace-of-shades'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/38096424-the-ragged-edge-of-night
# {'title': 'The Ragged Edge of Night', 'author': 'Olivia Hawker', 'language': 'English', 'avg_ratings': '4.15', 'ratings_count': '42,377', 'reviews_count': '3,429', 'publisher': 'Lake Union Publishing', 'publish_year': '2018', 'num_pages': 340, 'page_format': 'Kindle Edition', 'genres': ['Historical Fiction', 'Fiction', 'World War II', 'Historical', 'War', 'Germany', 'Audiobook', 'Holocaust', 'Adult', 'Family'], 'link': 'https://www.goodreads.com/book/show/38096424-the-ragged-edge-of-night'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/206196.The_Lions_of_Lucerne
# {'title': 'The Lions of Lucerne', 'author': 'Brad Thor', 'language': 'English', 'avg_ratings': '4.07', 'ratings_count': '39,002', 'reviews_count': '1,854', 'publisher': 'Pocket Star', 'publish_year': '2007', 'num_pages': 544, 'page_format': 'Mass Market Paperback', 'genres': ['Thriller', 'Fiction', 'Mystery', 'Action', 'Suspense', 'Espionage', 'Mystery Thriller', 'Spy Thriller', 'Audiobook', 'Adventure'], 'link': 'https://www.goodreads.com/book/show/206196.The_Lions_of_Lucerne'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/58470171-kingdom-of-the-feared
# {'title': 'Kingdom of the Feared', 'author': 'Kerri Maniscalco', 'language': 'English', 'avg_ratings': '3.91', 'ratings_count': '58,544', 'reviews_count': '7,706', 'publisher': 'Little, Brown Books for Young Readers', 'publish_year': '2022', 'num_pages': 464, 'page_format': 'Kindle Edition', 'genres': ['Fantasy', 'Romance', 'Young Adult', 'New Adult', 'Witches', 'Fantasy Romance', 'Paranormal', 'Fiction', 'Magic', 'Demons'], 'link': 'https://www.goodreads.com/book/show/58470171-kingdom-of-the-feared'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/58894.Daja_s_Book
# {'title': "Daja's Book", 'author': 'Tamora Pierce', 'language': 'English', 'avg_ratings': '4.12', 'ratings_count': '29,292', 'reviews_count': '507', 'publisher': 'Scholastic', 'publish_year': '2006', 'num_pages': 232, 'page_format': 'Mass Market Paperback', 'genres': ['Fantasy', 'Young Adult', 'Fiction', 'Magic', 'Young Adult Fantasy', 'Middle Grade', 'High Fantasy', 'Childrens', 'Science Fiction Fantasy', 'Teen'], 'link': 'https://www.goodreads.com/book/show/58894.Daja_s_Book'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/295654.Curse_of_the_Blue_Tattoo
# {'title': 'Curse of the Blue Tattoo: Being an Account of the Misadventures of Jacky Faber, Midshipman and Fine Lady', 'author': 'L.A. Meyer', 'language': 'English', 'avg_ratings': '4.27', 'ratings_count': '12,572', 'reviews_count': '962', 'publisher': 'Harcourt Paperbacks', 'publish_year': '2005', 'num_pages': 504, 'page_format': 'Paperback', 'genres': ['Historical Fiction', 'Young Adult', 'Adventure', 'Historical', 'Fiction', 'Pirates', 'Teen', 'Audiobook', 'Romance', 'Fantasy'], 'link': 'https://www.goodreads.com/book/show/295654.Curse_of_the_Blue_Tattoo'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/43805.Servant_of_the_Bones
# {'title': 'Servant of the Bones', 'author': 'Anne Rice', 'language': 'English', 'avg_ratings': '3.75', 'ratings_count': '30,061', 'reviews_count': '548', 'publisher': ' B E Trice Pub', 'publish_year': '1999', 'num_pages': 416, 'page_format': 'Hardcover', 'genres': ['Horror', 'Fantasy', 'Fiction', 'Paranormal', 'Supernatural', 'Vampires', 'Historical Fiction', 'Urban Fantasy', 'Gothic', 'Historical'], 'link': 'https://www.goodreads.com/book/show/43805.Servant_of_the_Bones'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/613991.The_King_Beyond_the_Gate
# {'title': 'The King Beyond the Gate', 'author': 'David Gemmell', 'language': 'English', 'avg_ratings': '4.14', 'ratings_count': '14,295', 'reviews_count': '315', 'publisher': 'Orbit ', 'publish_year': '1986', 'num_pages': 415, 'page_format': 'Paperback', 'genres': ['Fantasy', 'Fiction', 'Epic Fantasy', 'Heroic Fantasy', 'High Fantasy', 'Sword and Sorcery', 'Adventure', 'Science Fiction Fantasy', 'Epic', 'War'], 'link': 'https://www.goodreads.com/book/show/613991.The_King_Beyond_the_Gate'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/33299.The_Collected_Stories
# {'title': 'The Collected Stories', 'author': 'Amy Hempel', 'language': 'English', 'avg_ratings': '4.26', 'ratings_count': '6,978', 'reviews_count': '658', 'publisher': 'Scribner', 'publish_year': '2006', 'num_pages': 432, 'page_format': 'Hardcover', 'genres': ['Short Stories', 'Fiction', 'Literature', 'Contemporary', 'Literary Fiction', 'American', 'Womens', 'Female Authors', 'Short Story Collection', 'Adult Fiction'], 'link': 'https://www.goodreads.com/book/show/33299.The_Collected_Stories'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/17324.The_Visitation
# {'title': 'The Visitation', 'author': 'Frank E. Peretti', 'language': 'English', 'avg_ratings': '3.93', 'ratings_count': '20,615', 'reviews_count': '524', 'publisher': 'Thomas Nelson', 'publish_year': '2006', 'num_pages': 608, 'page_format': 'Paperback', 'genres': ['Christian Fiction', 'Fiction', 'Christian', 'Thriller', 'Horror', 'Fantasy', 'Suspense', 'Supernatural', 'Religion', 'Mystery'], 'link': 'https://www.goodreads.com/book/show/17324.The_Visitation'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/21278.Caught_Stealing
# {'title': 'Caught Stealing', 'author': 'Charlie Huston', 'language': 'English', 'avg_ratings': '4.04', 'ratings_count': '5,770', 'reviews_count': '513', 'publisher': 'Ballantine Books', 'publish_year': '2005', 'num_pages': 240, 'page_format': 'Paperback', 'genres': ['Fiction', 'Crime', 'Mystery', 'Thriller', 'Noir', 'Suspense', 'Mystery Thriller', 'Action', 'Pulp', 'Adventure'], 'link': 'https://www.goodreads.com/book/show/21278.Caught_Stealing'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/505576.Top_Girls
# {'title': 'Top Girls', 'author': 'Caryl Churchill', 'language': 'English', 'avg_ratings': '3.58', 'ratings_count': '9,148', 'reviews_count': '397', 'publisher': 'Methuen Publishing', 'publish_year': '2009', 'num_pages': 87, 'page_format': 'Paperback', 'genres': ['Plays', 'Drama', 'Theatre', 'Feminism', 'Fiction', 'School', 'Classics', '20th Century', 'Read For School', 'Literature'], 'link': 'https://www.goodreads.com/book/show/505576.Top_Girls'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/92755.The_Riddle_Master_of_Hed
# {'title': 'The Riddle-Master of Hed', 'author': 'Patricia A. McKillip', 'language': 'English', 'avg_ratings': '4.00', 'ratings_count': '12,318', 'reviews_count': '600', 'publisher': 'Del Rey / Ballantine', 'publish_year': '1980', 'num_pages': 240, 'page_format': 'Paperback', 'genres': ['Fantasy', 'Fiction', 'Young Adult', 'High Fantasy', 'Science Fiction Fantasy', 'Magic', 'Epic Fantasy', 'Adventure', 'Speculative Fiction', 'Classics'], 'link': 'https://www.goodreads.com/book/show/92755.The_Riddle_Master_of_Hed'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/8843789-ultraviolet
# {'title': 'Ultraviolet', 'author': 'R.J. Anderson', 'language': 'English', 'avg_ratings': '3.75', 'ratings_count': '9,442', 'reviews_count': '1,548', 'publisher': 'Orchard', 'publish_year': '2011', 'num_pages': 415, 'page_format': 'Paperback', 'genres': ['Young Adult', 'Science Fiction', 'Paranormal', 'Fantasy', 'Mystery', 'Aliens', 'Romance', 'Fiction', 'Supernatural', 'Contemporary'], 'link': 'https://www.goodreads.com/book/show/8843789-ultraviolet'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/616678.The_Diamond_Throne
# {'title': 'The Diamond Throne', 'author': 'David Eddings', 'language': 'English', 'avg_ratings': '3.97', 'ratings_count': '34,312', 'reviews_count': '643', 'publisher': 'Del Rey', 'publish_year': '1990', 'num_pages': 435, 'page_format': 'Mass Market Paperback', 'genres': ['Fantasy', 'Fiction', 'Epic Fantasy', 'High Fantasy', 'Science Fiction Fantasy', 'Adventure', 'Magic', 'Young Adult', 'Epic', 'Adult'], 'link': 'https://www.goodreads.com/book/show/616678.The_Diamond_Throne'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/202039.King_s_Dragon
# {'title': "King's Dragon", 'author': 'Kate Elliott', 'language': 'English', 'avg_ratings': '3.80', 'ratings_count': '9,122', 'reviews_count': '388', 'publisher': 'DAW Books', 'publish_year': '1998', 'num_pages': 636, 'page_format': 'Mass Market Paperback', 'genres': ['Fantasy', 'Fiction', 'Epic Fantasy', 'High Fantasy', 'Science Fiction Fantasy', 'Magic', 'Adult', 'Romance', 'Adventure', 'Epic'], 'link': 'https://www.goodreads.com/book/show/202039.King_s_Dragon'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/162612.Extinction
# {'title': 'Extinction', 'author': 'Thomas Bernhard', 'language': 'English', 'avg_ratings': '4.31', 'ratings_count': '2,613', 'reviews_count': '264', 'publisher': 'Quartet', 'publish_year': '1995', 'num_pages': 335, 'page_format': 'Paperback', 'genres': ['Fiction', 'German Literature', 'Classics', 'Literature', 'Novels', 'Literary Fiction', '20th Century', 'Humor', 'Collections', 'Germany'], 'link': 'https://www.goodreads.com/book/show/162612.Extinction'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/16045037-tidal
# {'title': 'Tidal', 'author': 'Amanda Hocking', 'language': 'English', 'avg_ratings': '3.93', 'ratings_count': '9,888', 'reviews_count': '644', 'publisher': "St. Martin's Griffin", 'publish_year': '2013', 'num_pages': 342, 'page_format': 'Hardcover', 'genres': ['Fantasy', 'Young Adult', 'Mermaids', 'Paranormal', 'Mythology', 'Romance', 'Fiction', 'Supernatural', 'Paranormal Romance', 'Urban Fantasy'], 'link': 'https://www.goodreads.com/book/show/16045037-tidal'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/16030817-empower
# {'title': 'Empower', 'author': 'Jessica Shirvington', 'language': 'English', 'avg_ratings': '4.60', 'ratings_count': '8,502', 'reviews_count': '791', 'publisher': 'Hachette ', 'publish_year': '2014', 'num_pages': 464, 'page_format': 'Paperback', 'genres': ['Angels', 'Young Adult', 'Fantasy', 'Paranormal', 'Romance', 'Supernatural', 'Paranormal Romance', 'Urban Fantasy', 'Magic', 'Fiction'], 'link': 'https://www.goodreads.com/book/show/16030817-empower'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/21481300-my-greek-traditional-cook-book-1
# {'title': 'My Greek Traditional Cook Book 1', 'author': 'Anna Othitis', 'language': 'English', 'avg_ratings': '4.80', 'ratings_count': '96', 'reviews_count': '22', 'publisher': 'Anna Othitis', 'publish_year': '2014', 'num_pages': 69, 'page_format': 'Kindle Edition', 'genres': ['Cookbooks', 'Cooking', 'Food'], 'link': 'https://www.goodreads.com/book/show/21481300-my-greek-traditional-cook-book-1'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/18405537-the-night-gardener
# {'title': 'The Night Gardener', 'author': 'Jonathan Auxier', 'language': 'English', 'avg_ratings': '4.06', 'ratings_count': '19,200', 'reviews_count': '3,148', 'publisher': 'Amulet Books', 'publish_year': '2014', 'num_pages': 350, 'page_format': 'Hardcover', 'genres': ['Fantasy', 'Middle Grade', 'Horror', 'Mystery', 'Young Adult', 'Fiction', 'Historical Fiction', 'Childrens', 'Juvenile', 'Supernatural'], 'link': 'https://www.goodreads.com/book/show/18405537-the-night-gardener'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/29430620-children-of-eden
# {'title': 'Children of Eden', 'author': 'Joey Graceffa', 'language': 'English', 'avg_ratings': '3.84', 'ratings_count': '11,022', 'reviews_count': '1,280', 'publisher': 'Atria/Keywords Press', 'publish_year': '2016', 'num_pages': 278, 'page_format': 'Hardcover', 'genres': ['Dystopia', 'Young Adult', 'Science Fiction', 'Fantasy', 'Fiction', 'Audiobook', 'Romance', 'LGBT', 'Post Apocalyptic', 'Queer'], 'link': 'https://www.goodreads.com/book/show/29430620-children-of-eden'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/46906.Fruits_Basket_Vol_15
# {'title': 'Fruits Basket, Vol. 15', 'author': 'Natsuki Takaya', 'language': 'English', 'avg_ratings': '4.47', 'ratings_count': '15,614', 'reviews_count': '217', 'publisher': 'Tokyopop', 'publish_year': '2006', 'num_pages': 196, 'page_format': 'Paperback', 'genres': ['Manga', 'Romance', 'Fantasy', 'Graphic Novels', 'Young Adult', 'Shojo', 'Fiction', 'Comics Manga', 'Comics', 'Anime'], 'link': 'https://www.goodreads.com/book/show/46906.Fruits_Basket_Vol_15'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/62779.Nada
# {'title': 'Nada', 'author': 'Carmen Laforet', 'language': 'English', 'avg_ratings': '3.84', 'ratings_count': '23,184', 'reviews_count': '2,129', 'publisher': 'Harvill Secker', 'publish_year': '2007', 'num_pages': 244, 'page_format': 'Hardcover', 'genres': ['Fiction', 'Classics', 'Spanish Literature', 'Spain', 'Historical Fiction', '20th Century', 'Womens', 'Novels', 'Literature', 'Drama'], 'link': 'https://www.goodreads.com/book/show/62779.Nada'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/16113.A_Dance_to_the_Music_of_Time
# {'title': 'A Dance to the Music of Time: 1st Movement', 'author': 'Anthony Powell', 'language': 'English', 'avg_ratings': '3.94', 'ratings_count': '4,535', 'reviews_count': '358', 'publisher': 'University of Chicago Press', 'publish_year': '1995', 'num_pages': 718, 'page_format': 'Paperback', 'genres': ['Fiction', 'Classics', 'Historical Fiction', 'British Literature', 'Literature', 'Novels', '20th Century', 'Literary Fiction', 'Audiobook', 'Historical'], 'link': 'https://www.goodreads.com/book/show/16113.A_Dance_to_the_Music_of_Time'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/1128399.Siewca_Wiatru
# {'title': 'Siewca Wiatru', 'author': 'Maja Lidia Kossakowska', 'language': 'Polish', 'avg_ratings': '3.88', 'ratings_count': '2,853', 'reviews_count': '48', 'publisher': 'Fabryka Słów', 'publish_year': '2004', 'num_pages': 560, 'page_format': 'Paperback', 'genres': ['Fantasy', 'Polish Literature', 'Angels', 'Urban Fantasy', 'Fiction', 'Audiobook', 'Paranormal', 'Favorites', 'Mine', 'Poland'], 'link': 'https://www.goodreads.com/book/show/1128399.Siewca_Wiatru'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/522471.Hope_Was_Here
# {'title': 'Hope Was Here', 'author': 'Joan Bauer', 'language': 'English', 'avg_ratings': '4.01', 'ratings_count': '20,504', 'reviews_count': '1,790', 'publisher': 'Puffin Books', 'publish_year': '2005', 'num_pages': 186, 'page_format': 'Paperback', 'genres': ['Young Adult', 'Realistic Fiction', 'Fiction', 'Contemporary', 'Middle Grade', 'Teen', 'Coming Of Age', 'Family', 'Childrens', 'School'], 'link': 'https://www.goodreads.com/book/show/522471.Hope_Was_Here'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/23218.Missing_You
# {'title': 'Missing You', 'author': 'Meg Cabot', 'language': 'English', 'avg_ratings': '4.18', 'ratings_count': '12,285', 'reviews_count': '425', 'publisher': 'HarperTempest', 'publish_year': '2006', 'num_pages': 268, 'page_format': 'Paperback', 'genres': ['Young Adult', 'Paranormal', 'Romance', 'Fantasy', 'Mystery', 'Teen', 'Chick Lit', 'Supernatural', 'Fiction', 'Contemporary'], 'link': 'https://www.goodreads.com/book/show/23218.Missing_You'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/121622.Mrs_McGinty_s_Dead
# {'title': "Mrs. McGinty's Dead", 'author': 'Agatha Christie', 'language': 'English', 'avg_ratings': '3.85', 'ratings_count': '29,580', 'reviews_count': '1,575', 'publisher': 'AudioGO', 'publish_year': '2007', 'num_pages': 244, 'page_format': 'Audio CD', 'genres': ['Mystery', 'Fiction', 'Crime', 'Classics', 'Detective', 'Mystery Thriller', 'Audiobook', 'Murder Mystery', 'British Literature', 'Thriller'], 'link': 'https://www.goodreads.com/book/show/121622.Mrs_McGinty_s_Dead'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/25743.The_Slave
# {'title': 'The Slave', 'author': 'Isaac Bashevis Singer', 'language': 'English', 'avg_ratings': '4.21', 'ratings_count': '3,398', 'reviews_count': '317', 'publisher': 'Farrar, Straus and Giroux', 'publish_year': '1988', 'num_pages': 320, 'page_format': 'Paperback', 'genres': ['Fiction', 'Historical Fiction', 'Classics', 'Jewish', 'Nobel Prize', 'Poland', 'Novels', 'Literature', 'Historical', 'Polish Literature'], 'link': 'https://www.goodreads.com/book/show/25743.The_Slave'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/13060609-dark-kiss
# {'title': 'Dark Kiss', 'author': 'Michelle Rowen', 'language': 'English', 'avg_ratings': '3.82', 'ratings_count': '8,139', 'reviews_count': '681', 'publisher': 'Harlequin Teen', 'publish_year': '2012', 'num_pages': 352, 'page_format': 'Paperback', 'genres': ['Angels', 'Young Adult', 'Paranormal', 'Romance', 'Demons', 'Fantasy', 'Paranormal Romance', 'Urban Fantasy', 'Supernatural', 'Fiction'], 'link': 'https://www.goodreads.com/book/show/13060609-dark-kiss'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/9266810-ten-things-we-did
# {'title': 'Ten Things We Did', 'author': 'Sarah Mlynowski', 'language': 'English', 'avg_ratings': '3.72', 'ratings_count': '19,646', 'reviews_count': '1,863', 'publisher': 'HarperTeen', 'publish_year': '2011', 'num_pages': 368, 'page_format': 'Hardcover', 'genres': ['Young Adult', 'Romance', 'Contemporary', 'Chick Lit', 'Realistic Fiction', 'Fiction', 'Teen', 'Young Adult Contemporary', 'High School', 'Young Adult Romance'], 'link': 'https://www.goodreads.com/book/show/9266810-ten-things-we-did'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/15733160-meditation-on-space-time
# {'title': 'Meditation on Space-Time', 'author': 'Leonard Seet', 'language': 'English', 'avg_ratings': '3.87', 'ratings_count': '30', 'reviews_count': '10', 'publisher': 'Excelsior Publishing', 'publish_year': '2012', 'num_pages': 236, 'page_format': 'Paperback', 'genres': ['Philosophy', 'Fiction', 'Literature'], 'link': 'https://www.goodreads.com/book/show/15733160-meditation-on-space-time'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/19336.The_Tale_of_Jemima_Puddle_Duck
# {'title': 'The Tale of Jemima Puddle-Duck', 'author': 'Beatrix Potter', 'language': 'English', 'avg_ratings': '4.05', 'ratings_count': '13,432', 'reviews_count': '362', 'publisher': 'Frederick Warne', 'publish_year': '2002', 'num_pages': 57, 'page_format': 'Hardcover', 'genres': ['Childrens', 'Picture Books', 'Classics', 'Fiction', 'Animals', 'Fantasy', 'Short Stories', 'British Literature', 'Juvenile', 'Childrens Classics'], 'link': 'https://www.goodreads.com/book/show/19336.The_Tale_of_Jemima_Puddle_Duck'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/10816908-the-crown-of-embers
# {'title': 'The Crown of Embers', 'author': 'Rae Carson', 'language': 'English', 'avg_ratings': '4.17', 'ratings_count': '46,341', 'reviews_count': '3,446', 'publisher': 'Greenwillow Books', 'publish_year': '2012', 'num_pages': 410, 'page_format': 'Hardcover', 'genres': ['Fantasy', 'Young Adult', 'Romance', 'Magic', 'Young Adult Fantasy', 'Fiction', 'High Fantasy', 'Adventure', 'Teen', 'Audiobook'], 'link': 'https://www.goodreads.com/book/show/10816908-the-crown-of-embers'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/13380915-zom-b
# {'title': 'Zom-B', 'author': 'Darren Shan', 'language': 'English', 'avg_ratings': '3.58', 'ratings_count': '8,091', 'reviews_count': '1,250', 'publisher': 'Simon & Schuster', 'publish_year': '2012', 'num_pages': 217, 'page_format': 'Hardcover', 'genres': ['Horror', 'Zombies', 'Young Adult', 'Fiction', 'Fantasy', 'Teen', 'Paranormal', 'Science Fiction', 'Audiobook', 'Apocalyptic'], 'link': 'https://www.goodreads.com/book/show/13380915-zom-b'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/6633007-solitary
# {'title': 'Solitary', 'author': 'Alexander Gordon Smith', 'language': 'English', 'avg_ratings': '4.18', 'ratings_count': '8,386', 'reviews_count': '842', 'publisher': '', 'publish_year': '2009', 'num_pages': 272, 'page_format': 'Paperback', 'genres': ['Young Adult', 'Horror', 'Science Fiction', 'Dystopia', 'Thriller', 'Fiction', 'Fantasy', 'Adventure', 'Teen', 'Survival'], 'link': 'https://www.goodreads.com/book/show/6633007-solitary'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/466405.La_Nuit_des_temps
# {'title': 'La Nuit des temps', 'author': 'René Barjavel', 'language': 'French', 'avg_ratings': '4.07', 'ratings_count': '11,820', 'reviews_count': '653', 'publisher': 'Pocket', 'publish_year': '1988', 'num_pages': 394, 'page_format': 'Mass Market Paperback', 'genres': ['Science Fiction', 'France', 'Fiction', 'Classics', 'Romance', 'Roman', 'French Literature', 'Fantasy', 'School', 'Novels'], 'link': 'https://www.goodreads.com/book/show/466405.La_Nuit_des_temps'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/27391093-the-quirky-tale-of-april-hale
# {'title': 'The Quirky Tale of April Hale', 'author': 'Cathy Octo', 'language': 'English', 'avg_ratings': '4.10', 'ratings_count': '3,531', 'reviews_count': '247', 'publisher': 'Blvnp Publishing Incorporated', 'publish_year': '2015', 'num_pages': 273, 'page_format': 'Kindle Edition', 'genres': ['Romance', 'Contemporary', 'Young Adult', 'High School', 'Humor', 'Fiction', 'Contemporary Romance', 'Realistic Fiction', 'Chick Lit', 'Teen'], 'link': 'https://www.goodreads.com/book/show/27391093-the-quirky-tale-of-april-hale'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/19405297-we-are-all-made-of-molecules
# {'title': 'We Are All Made of Molecules', 'author': 'Susin Nielsen', 'language': 'English', 'avg_ratings': '3.83', 'ratings_count': '14,659', 'reviews_count': '2,090', 'publisher': 'Wendy Lamb Books ', 'publish_year': '2015', 'num_pages': 256, 'page_format': 'Kindle Edition', 'genres': ['Young Adult', 'Contemporary', 'Realistic Fiction', 'Fiction', 'Middle Grade', 'LGBT', 'Family', 'Teen', 'Audiobook', 'Canada'], 'link': 'https://www.goodreads.com/book/show/19405297-we-are-all-made-of-molecules'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/34967829-sick-fux
# {'title': 'Sick Fux', 'author': 'Tillie Cole', 'language': 'English', 'avg_ratings': '3.95', 'ratings_count': '13,307', 'reviews_count': '2,829', 'publisher': '', 'publish_year': '2017', 'num_pages': 314, 'page_format': 'ebook', 'genres': ['Dark', 'Romance', 'Abuse', 'New Adult', 'Contemporary', 'Horror', 'Erotica', 'Adult', 'Crime', 'Contemporary Romance'], 'link': 'https://www.goodreads.com/book/show/34967829-sick-fux'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/30359743-noble-beginnings
# {'title': 'Noble Beginnings', 'author': 'L.T. Ryan', 'language': 'English', 'avg_ratings': '3.86', 'ratings_count': '22,228', 'reviews_count': '974', 'publisher': '', 'publish_year': '2013', 'num_pages': 222, 'page_format': 'Kindle Edition', 'genres': ['Thriller', 'Fiction', 'Mystery', 'Action', 'Mystery Thriller', 'Military Fiction', 'Suspense', 'Adventure', 'Amazon', 'Conspiracy Theories'], 'link': 'https://www.goodreads.com/book/show/30359743-noble-beginnings'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/29431081-the-universe-of-us-volume-4
# {'title': 'The Universe of Us (Volume 4)', 'author': 'Lang Leav', 'language': 'English', 'avg_ratings': '4.06', 'ratings_count': '18,508', 'reviews_count': '1,292', 'publisher': 'Andrews McMeel Publishing', 'publish_year': '2016', 'num_pages': 225, 'page_format': 'Paperback', 'genres': ['Poetry', 'Romance', 'Contemporary', 'Nonfiction', 'Love', 'Adult', 'Short Stories'], 'link': 'https://www.goodreads.com/book/show/29431081-the-universe-of-us-volume-4'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/38743281-the-beast-within
# {'title': 'The Beast Within', 'author': 'Liz  Cowan', 'language': 'English', 'avg_ratings': '3.90', 'ratings_count': '180', 'reviews_count': '19', 'publisher': 'self', 'publish_year': '2018', 'num_pages': 338, 'page_format': 'Paperback/Kindle', 'genres': ['Romance', 'Contemporary', 'Young Adult', 'Fiction', 'Adult', 'Mystery', 'New Adult', 'Love Story', 'Novels', 'Teen'], 'link': 'https://www.goodreads.com/book/show/38743281-the-beast-within'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/33195916-dying-to-give
# {'title': 'Dying to Give', 'author': 'Gary B.  Shelly', 'language': 'English', 'avg_ratings': '4.28', 'ratings_count': '109', 'reviews_count': '4', 'publisher': 'Smitch Pilot Publishing', 'publish_year': '2016', 'num_pages': 404, 'page_format': 'Kindle Edition', 'genres': ['New Adult', 'Fiction', 'Contemporary', 'Adult', 'Novels', 'Young Adult'], 'link': 'https://www.goodreads.com/book/show/33195916-dying-to-give'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/35297394-the-wicked-deep
# {'title': 'The Wicked Deep', 'author': 'Shea Ernshaw', 'language': 'English', 'avg_ratings': '3.86', 'ratings_count': '36,782', 'reviews_count': '7,391', 'publisher': 'Simon & Schuster Books for Young Readers', 'publish_year': '2018', 'num_pages': 310, 'page_format': 'Hardcover', 'genres': ['Fantasy', 'Young Adult', 'Paranormal', 'Witches', 'Romance', 'Fiction', 'Young Adult Fantasy', 'Mystery', 'Magic', 'Supernatural'], 'link': 'https://www.goodreads.com/book/show/35297394-the-wicked-deep'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/30038906-the-names-they-gave-us
# ...
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/3247019
# {'title': 'Лабиринт отражений', 'author': 'Sergei Lukyanenko', 'language': 'Russian', 'avg_ratings': '4.14', 'ratings_count': '4,918', 'reviews_count': '89', 'publisher': 'AST', 'publish_year': '1999', 'num_pages': 480, 'page_format': 'Hardcover', 'genres': ['Science Fiction', 'Fiction', 'Russia', 'Fantasy', 'Cyberpunk', 'Russian Literature', 'Science Fiction Fantasy', 'Urban Fantasy', 'Audiobook', 'German Literature'], 'link': 'https://www.goodreads.com/book/show/3247019'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/3392285-dead-is-a-state-of-mind
# {'title': 'Dead Is a State of Mind', 'author': 'Marlene Perez', 'language': 'English', 'avg_ratings': '4.13', 'ratings_count': '6,639', 'reviews_count': '404', 'publisher': 'Clarion Books', 'publish_year': '2009', 'num_pages': 175, 'page_format': 'Paperback', 'genres': ['Young Adult', 'Paranormal', 'Fantasy', 'Mystery', 'Vampires', 'Supernatural', 'Romance', 'Werewolves', 'Fiction', 'Teen'], 'link': 'https://www.goodreads.com/book/show/3392285-dead-is-a-state-of-mind'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/296264.The_Black_Arrow
# {'title': 'The Black Arrow', 'author': 'Robert Louis Stevenson', 'language': 'English', 'avg_ratings': '3.80', 'ratings_count': '18,178', 'reviews_count': '775', 'publisher': 'Adamant Media Corporation', 'publish_year': '2001', 'num_pages': 242, 'page_format': 'Paperback', 'genres': ['Classics', 'Historical Fiction', 'Fiction', 'Adventure', 'Historical', 'Young Adult', 'Literature', 'Romance', 'British Literature', '19th Century'], 'link': 'https://www.goodreads.com/book/show/296264.The_Black_Arrow'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/415909.No_Greater_Love
# {'title': 'No Greater Love', 'author': 'Danielle Steel', 'language': 'English', 'avg_ratings': '4.01', 'ratings_count': '10,628', 'reviews_count': '398', 'publisher': 'Dell', 'publish_year': '2007', 'num_pages': 416, 'page_format': 'Mass Market Paperback', 'genres': ['Romance', 'Fiction', 'Historical Fiction', 'Historical Romance', 'Chick Lit', 'Historical', 'Contemporary', 'Drama', 'Novels', 'Adult Fiction'], 'link': 'https://www.goodreads.com/book/show/415909.No_Greater_Love'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/48811.Nancy_Drew
# {'title': 'Nancy Drew: #1-64', 'author': 'Carolyn Keene', 'language': 'English', 'avg_ratings': '4.23', 'ratings_count': '19,390', 'reviews_count': '497', 'publisher': 'Grosset & Dunlap', 'publish_year': '2006', 'num_pages': None, 'page_format': 'Hardcover', 'genres': ['Mystery', 'Childrens', 'Young Adult', 'Fiction', 'Classics', 'Middle Grade', 'Mystery Thriller', 'Adventure', 'Suspense', 'Kids'], 'link': 'https://www.goodreads.com/book/show/48811.Nancy_Drew'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/8341567-the-perfect-play
# {'title': 'The Perfect Play', 'author': 'Jaci Burton', 'language': 'English', 'avg_ratings': '3.89', 'ratings_count': '39,173', 'reviews_count': '2,106', 'publisher': 'Berkley Heat', 'publish_year': '2011', 'num_pages': 324, 'page_format': 'Trade Paperback', 'genres': ['Romance', 'Sports', 'Sports Romance', 'Contemporary Romance', 'Contemporary', 'Erotica', 'Adult', 'Erotic Romance', 'Football', 'Chick Lit'], 'link': 'https://www.goodreads.com/book/show/8341567-the-perfect-play'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/2294984.All_the_Lovely_Bad_Ones
# {'title': 'All the Lovely Bad Ones', 'author': 'Mary Downing Hahn', 'language': 'English', 'avg_ratings': '4.03', 'ratings_count': '11,098', 'reviews_count': '1,094', 'publisher': 'Clarion Books', 'publish_year': '2008', 'num_pages': 182, 'page_format': 'Hardcover', 'genres': ['Horror', 'Mystery', 'Middle Grade', 'Fiction', 'Ghosts', 'Paranormal', 'Fantasy', 'Young Adult', 'Ghost Stories', 'Childrens'], 'link': 'https://www.goodreads.com/book/show/2294984.All_the_Lovely_Bad_Ones'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/6023056-act-like-a-lady-think-like-a-man
# {'title': 'Act Like a Lady, Think Like a Man: What Men Really Think About Love, Relationships, Intimacy, and Commitment', 'author': 'Steve  Harvey', 'language': 'English', 'avg_ratings': '3.79', 'ratings_count': '47,089', 'reviews_count': '3,372', 'publisher': 'Amistad', 'publish_year': '2009', 'num_pages': 232, 'page_format': 'Hardcover', 'genres': ['Nonfiction', 'Self Help', 'Relationships', 'Psychology', 'Humor', 'Personal Development', 'Love', 'Adult', 'Romance', 'Inspirational'], 'link': 'https://www.goodreads.com/book/show/6023056-act-like-a-lady-think-like-a-man'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/10084.River_of_Blue_Fire
# {'title': 'River of Blue Fire', 'author': 'Tad Williams', 'language': 'English', 'avg_ratings': '4.03', 'ratings_count': '15,715', 'reviews_count': '332', 'publisher': 'DAW', 'publish_year': '1999', 'num_pages': 675, 'page_format': 'Mass Market Paperback', 'genres': ['Fantasy', 'Science Fiction', 'Fiction', 'Cyberpunk', 'Science Fiction Fantasy', 'Adventure', 'Speculative Fiction', 'Epic Fantasy', 'Epic', 'Audiobook'], 'link': 'https://www.goodreads.com/book/show/10084.River_of_Blue_Fire'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/17285983-the-rocker-that-holds-me
# {'title': 'The Rocker That Holds Me', 'author': 'Terri Anne Browning', 'language': 'English', 'avg_ratings': '3.90', 'ratings_count': '19,544', 'reviews_count': '1,084', 'publisher': 'Anna Henson', 'publish_year': '2013', 'num_pages': 102, 'page_format': 'Kindle Edition', 'genres': ['Romance', 'New Adult', 'Music', 'Contemporary', 'Contemporary Romance', 'Abuse', 'Adult', 'Musicians', 'Novella', 'Erotica'], 'link': 'https://www.goodreads.com/book/show/17285983-the-rocker-that-holds-me'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/21400356-debt-inheritance
# {'title': 'Debt Inheritance', 'author': 'Pepper Winters', 'language': 'English', 'avg_ratings': '3.77', 'ratings_count': '25,729', 'reviews_count': '2,698', 'publisher': 'CreateSpace', 'publish_year': '2014', 'num_pages': 222, 'page_format': 'Paperback', 'genres': ['Dark', 'Romance', 'Erotica', 'BDSM', 'Abuse', 'Adult', 'Contemporary', 'Contemporary Romance', 'Suspense', 'Erotic Romance'], 'link': 'https://www.goodreads.com/book/show/21400356-debt-inheritance'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/60483.Music_for_Chameleons
# {'title': 'Music for Chameleons', 'author': 'Truman Capote', 'language': 'English', 'avg_ratings': '4.09', 'ratings_count': '10,193', 'reviews_count': '681', 'publisher': 'Penguin', 'publish_year': '2001', 'num_pages': 262, 'page_format': 'Paperback', 'genres': ['Short Stories', 'Fiction', 'Classics', 'Essays', 'Literature', 'American', 'True Crime', 'Literary Fiction', '20th Century', 'The United States Of America'], 'link': 'https://www.goodreads.com/book/show/60483.Music_for_Chameleons'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/685391.Iron_Silk
# {'title': 'Iron &  Silk', 'author': 'Mark Salzman', 'language': 'English', 'avg_ratings': '3.96', 'ratings_count': '3,426', 'reviews_count': '259', 'publisher': 'Vintage', 'publish_year': '1987', 'num_pages': 224, 'page_format': 'Paperback', 'genres': ['China', 'Nonfiction', 'Travel', 'Memoir', 'Martial Arts', 'Asia', 'Biography', 'Biography Memoir', 'History', 'Autobiography'], 'link': 'https://www.goodreads.com/book/show/685391.Iron_Silk'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/10852.Cosmic_Banditos
# {'title': 'Cosmic Banditos', 'author': 'A.C. Weisbecker', 'language': 'English', 'avg_ratings': '4.07', 'ratings_count': '2,226', 'reviews_count': '196', 'publisher': 'Berkley', 'publish_year': '2001', 'num_pages': 224, 'page_format': 'Paperback', 'genres': ['Fiction', 'Science Fiction', 'Humor', 'Comedy', 'Adventure', 'Novels', 'Roman', 'Literature', 'Literary Fiction', 'Philosophy'], 'link': 'https://www.goodreads.com/book/show/10852.Cosmic_Banditos'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/2005841.The_Proper_Role_of_Government
# {'title': 'The Proper Role of Government', 'author': 'Ezra Taft Benson', 'language': 'English', 'avg_ratings': '4.46', 'ratings_count': '546', 'reviews_count': '59', 'publisher': '', 'publish_year': '1968', 'num_pages': 24, 'page_format': 'Kindle Edition', 'genres': ['Politics', 'Nonfiction', 'History', 'Philosophy', 'Government', 'Religion', 'Lds', 'American History', 'Economics', 'Classics'], 'link': 'https://www.goodreads.com/book/show/2005841.The_Proper_Role_of_Government'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/20657.Some_Ether
# {'title': 'Some Ether', 'author': 'Nick Flynn', 'language': 'English', 'avg_ratings': '4.15', 'ratings_count': '1,780', 'reviews_count': '103', 'publisher': 'Graywolf Press', 'publish_year': '2000', 'num_pages': 85, 'page_format': 'Paperback', 'genres': ['Poetry', 'American', 'Fiction'], 'link': 'https://www.goodreads.com/book/show/20657.Some_Ether'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/59825.Inner_Harbor
# {'title': 'Inner Harbor', 'author': 'Nora Roberts', 'language': 'English', 'avg_ratings': '4.18', 'ratings_count': '33,561', 'reviews_count': '782', 'publisher': 'Berkley Books', 'publish_year': '1999', 'num_pages': 324, 'page_format': 'Mass Market Paperback', 'genres': ['Romance', 'Contemporary Romance', 'Fiction', 'Contemporary', 'Chick Lit', 'Adult', 'Audiobook', 'Family', 'Mystery', 'Adult Fiction'], 'link': 'https://www.goodreads.com/book/show/59825.Inner_Harbor'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/99245.Nightfall
# {'title': 'Nightfall', 'author': 'Isaac Asimov', 'language': 'English', 'avg_ratings': '4.05', 'ratings_count': '34,783', 'reviews_count': '990', 'publisher': 'Bantam Books', 'publish_year': '2012', 'num_pages': 339, 'page_format': 'Mass Market Paperback', 'genres': ['Science Fiction', 'Fiction', 'Science Fiction Fantasy', 'Fantasy', 'Classics', 'Short Stories', 'Speculative Fiction', 'Post Apocalyptic', 'Dystopia', 'Novels'], 'link': 'https://www.goodreads.com/book/show/99245.Nightfall'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/6419887-the-boy-who-harnessed-the-wind
# {'title': 'The Boy Who Harnessed the Wind: Creating Currents of Electricity and Hope', 'author': 'William Kamkwamba', 'language': 'English', 'avg_ratings': '4.07', 'ratings_count': '28,666', 'reviews_count': '4,089', 'publisher': 'William Morrow', 'publish_year': '2009', 'num_pages': 270, 'page_format': 'Hardcover', 'genres': ['Nonfiction', 'Africa', 'Memoir', 'Biography', 'Science', 'Biography Memoir', 'Malawi', 'Autobiography', 'School', 'Inspirational'], 'link': 'https://www.goodreads.com/book/show/6419887-the-boy-who-harnessed-the-wind'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/1289436.Why_the_Whales_Came
# {'title': 'Why the Whales Came', 'author': 'Michael Morpurgo', 'language': 'English', 'avg_ratings': '3.95', 'ratings_count': '4,350', 'reviews_count': '238', 'publisher': 'Egmont', 'publish_year': '2007', 'num_pages': 180, 'page_format': 'Paperback', 'genres': ['Childrens', 'Fiction', 'Historical Fiction', 'Animals', 'Middle Grade', 'School', 'Novels', 'Young Adult', 'Mystery', 'Contemporary'], 'link': 'https://www.goodreads.com/book/show/1289436.Why_the_Whales_Came'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/216378.Now_Wait_for_Last_Year
# {'title': 'Now Wait for Last Year', 'author': 'Philip K. Dick', 'language': 'English', 'avg_ratings': '3.88', 'ratings_count': '6,543', 'reviews_count': '353', 'publisher': 'Vintage', 'publish_year': '1993', 'num_pages': 230, 'page_format': 'Paperback', 'genres': ['Science Fiction', 'Fiction', 'Time Travel', 'Novels', 'Speculative Fiction', 'Science Fiction Fantasy', '20th Century', 'American', 'Dystopia', 'Classics'], 'link': 'https://www.goodreads.com/book/show/216378.Now_Wait_for_Last_Year'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/494320.In_My_Hands
# {'title': 'In My Hands: Memories of a Holocaust Rescuer', 'author': 'Irene Gut Opdyke', 'language': 'English', 'avg_ratings': '4.24', 'ratings_count': '14,007', 'reviews_count': '1,098', 'publisher': 'Laurel Leaf', 'publish_year': '2004', 'num_pages': 304, 'page_format': 'Paperback', 'genres': ['Nonfiction', 'Holocaust', 'History', 'Memoir', 'World War II', 'Biography', 'War', 'Historical', 'Biography Memoir', 'Autobiography'], 'link': 'https://www.goodreads.com/book/show/494320.In_My_Hands'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/1134122.The_Power_of_Positive_Thinking
# {'title': 'The Power of Positive Thinking', 'author': 'Norman Vincent Peale', 'language': 'English', 'avg_ratings': '4.17', 'ratings_count': '104,450', 'reviews_count': '1,926', 'publisher': 'Fireside', 'publish_year': '2007', 'num_pages': 128, 'page_format': 'Hardcover', 'genres': ['Self Help', 'Nonfiction', 'Psychology', 'Personal Development', 'Business', 'Philosophy', 'Inspirational', 'Spirituality', 'Leadership', 'Religion'], 'link': 'https://www.goodreads.com/book/show/1134122.The_Power_of_Positive_Thinking'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/11746102-biting-cold
# {'title': 'Biting Cold', 'author': 'Chloe Neill', 'language': 'English', 'avg_ratings': '4.12', 'ratings_count': '24,907', 'reviews_count': '1,394', 'publisher': 'New American Library', 'publish_year': '2012', 'num_pages': 352, 'page_format': 'Trade Paperback', 'genres': ['Urban Fantasy', 'Vampires', 'Paranormal', 'Fantasy', 'Romance', 'Paranormal Romance', 'Magic', 'Adult', 'Witches', 'Angels'], 'link': 'https://www.goodreads.com/book/show/11746102-biting-cold'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/7148256-the-red-queen
# {'title': 'The Red Queen', 'author': 'Philippa Gregory', 'language': 'English', 'avg_ratings': '3.81', 'ratings_count': '70,788', 'reviews_count': '4,944', 'publisher': 'Atria Books', 'publish_year': '2010', 'num_pages': 412, 'page_format': 'Hardcover', 'genres': ['Historical Fiction', 'Fiction', 'Historical', 'British Literature', 'Adult', 'Romance', 'Tudor Period', 'Audiobook', 'Historical Romance', '15th Century'], 'link': 'https://www.goodreads.com/book/show/7148256-the-red-queen'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/12651.The_Social_Contract
# {'title': 'The Social Contract', 'author': 'Jean-Jacques Rousseau', 'language': 'English', 'avg_ratings': '3.78', 'ratings_count': '46,345', 'reviews_count': '1,311', 'publisher': 'Penguin', 'publish_year': '2006', 'num_pages': 168, 'page_format': 'Paperback', 'genres': ['Philosophy', 'Politics', 'Nonfiction', 'Classics', 'History', 'France', 'Political Science', 'Sociology', '18th Century', 'French Literature'], 'link': 'https://www.goodreads.com/book/show/12651.The_Social_Contract'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/204276.Split_Second
# {'title': 'Split Second', 'author': 'David Baldacci', 'language': 'English', 'avg_ratings': '4.03', 'ratings_count': '70,551', 'reviews_count': '2,951', 'publisher': 'Vision', 'publish_year': '2004', 'num_pages': 512, 'page_format': 'Mass Market Paperback', 'genres': ['Mystery', 'Fiction', 'Thriller', 'Crime', 'Suspense', 'Mystery Thriller', 'Audiobook', 'Action', 'Detective', 'Adult'], 'link': 'https://www.goodreads.com/book/show/204276.Split_Second'}
# crawled and saved

# %% [markdown]
# ### Get 10.000 books details (100 book in one page)

# %% [markdown]
# ### test crawl a book

# %%
# try:
#     bookURL = 'https://www.goodreads.com/book/show/77203.The_Kite_Runner'
#     # bookURL = 'https://www.goodreads.com/book/show/18626461-messages-from-heaven'
#     soup = get_soup(bookURL)
#     bookDetails = get_book_details_dict(soup)
#     bookDetails['link'] = bookURL
#     add_dict_to_csv(bookDetails.values())
#     print(bookDetails)
# except Exception as e:
#     print("Error:", e)
#     winsound.Beep(440, 2000)  # phát ra âm thanh nếu có lỗi
#     raise e
