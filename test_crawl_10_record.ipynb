# %% [markdown]
# # Import thư viện

# %%
from bs4 import BeautifulSoup
import requests
import json
import csv
import os

# %% [markdown]
# # Util

# %% [markdown]
# ### Write Json to .json

# %%
def writeJsonToFile(html):
    with open('out.json', 'w') as f:
        return json.dump(html, f)

# %% [markdown]
# ### Write records to .csv

# %%
def add_dict_to_csv(dict):
    # Mở file CSV trong chế độ ghi
    filePath = "./raw_data_10_record.csv"
    mode = None
    if not os.path.isfile(filePath):
      mode = "w"
    else:
      mode = "a"
    with open(filePath, mode=mode, newline="", encoding="utf-8") as file:
        # Tạo writer object
        writer = csv.writer(file)
        # Ghi data row
        writer.writerow(dict)

# %% [markdown]
# ### Convert Timestamp to year

# %%
import datetime
def convert_timestamp_to_year(timestamp):
    seconds = abs(timestamp) // 1000
    formatted_year = None
    try:
        delta = datetime.timedelta(seconds=seconds)
        epoch = datetime.datetime(1970, 1, 1)
        if timestamp < 0:
            date = epoch - delta
        else:
            date = epoch + delta
        formatted_year = date.strftime("%Y")
        return formatted_year
    except Exception as e:
        return None

# %% [markdown]
# # I.    CRAWL DATA

# %%
book_dict_origin = {
    'title':None, #tiêu đề sách
    'author':None, #tác giả
    'language':None, #ngôn ngữ của sách
    'avg_ratings':None, # điểm đánh giá
    'ratings_count':None, # số lượng ratings
    'reviews_count':None, # số lượng reviews
    'publisher':None, # nhà/người phát hành
    'publish_year':None, # Năm phát hành
    'num_pages':None, # số trang
    'page_format':None, # loại bìa
    'genres':None, # Thể loại
    'link':None # link sách
}

# %%
def get_soup(bookURL):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Chrome/4.0.209.0 Safari/532.0'}
    status = None
    response = None
    while(status != 200):
        try:
            response = requests.get(bookURL, headers=headers)
            status = response.status_code
        except Exception as e:
            print(e)
    html_content = response.content
    soup = BeautifulSoup(html_content, 'html.parser')
    return soup

# %%
def get_book_details_dict(soup):
    book_dict = book_dict_origin
    
    # Title
    title = soup.find('h1', {'class':'Text__title1'}).text
    book_dict['title'] = title

    # Author
    author = soup.find('span', {'class':'ContributorLink__name'}).text
    book_dict['author'] = author

    # Voters-count
    ratings_count = soup.find('span', {'data-testid':'ratingsCount'}).text.split()[0]
    book_dict['ratings_count'] = ratings_count

    # Rating
    avg_ratings = soup.find('div', {'class':'RatingStatistics__rating'}).text
    book_dict['avg_ratings'] = avg_ratings

    # Reviews-count
    reviews_count = soup.find('span', {'data-testid':'reviewsCount'}).text.split()[0]
    book_dict['reviews_count'] = reviews_count

    # Raw details
    script_tag_book_details_raw = soup.find('script', {'type': 'application/json'}).get_text()
    script_tag_book_details = json.loads(script_tag_book_details_raw)['props']['pageProps']['apolloState']
    # writeJsonToFile(json.loads(script_tag_book_details_raw))
    book_details_wrap = next(iter({key: val for key, val in script_tag_book_details.items() if "Book:" in key and "details" in val}.values()))
    book_details = book_details_wrap['details']
    # Publisher
    publisher = book_details['publisher']   
    book_dict['publisher'] = publisher

    # Language
    language = book_details['language']['name']
    book_dict['language'] = language

    # published
    timestamp = book_details['publicationTime']# millisecond
    formatted_year = None
    if(timestamp):
        formatted_year = convert_timestamp_to_year(timestamp)
        book_dict['publish_year'] = formatted_year
    else:
        book_dict['publish_year'] = formatted_year
    

    # Pages-count
    num_pages = book_details['numPages']
    book_dict['num_pages'] = num_pages

    # Pages-count
    page_format = book_details['format']
    book_dict['page_format'] = page_format

    #Genres
    genres = book_details_wrap['bookGenres']
    genresList = []
    if(genres):
      if(len(genres)>0):
          for item in genres:
              genresList.append(item['genre']['name'])
          book_dict['genres'] = genresList
    return book_dict

# %% [markdown]
# ### Get 10 book

# %%
try:
    rootURL = 'https://www.goodreads.com'

    # create csv header ()
    add_dict_to_csv(book_dict_origin.keys())

    #  crawl and save to csv
    count = 0
    isBreak = False;
    for i in range(1,101):
        # list book of page i
        ListBookURL = f'https://www.goodreads.com/list/show/1.Best_Books_Ever?page={i}'
        # get soup
        listBook_soup = None
        while(True):
            listBook_soup = get_soup(ListBookURL)
            # check get list book
            if(books := listBook_soup.find_all('a', {'class':'bookTitle'})):
                break
            
        books = listBook_soup.find_all('a', {'class':'bookTitle'})
        # link of book
        for book in books:
            # get link
            bookURL = rootURL+book['href']
            
            print("fetching data...",bookURL)
            # get soup
            bookSoup = None
            while(True):
                bookSoup = bookSoup = get_soup(bookURL)
                if(bookSoup.find('h1', {'class':'Text__title1'})):
                    break

            # get detais
            bookDetails = get_book_details_dict(bookSoup)
            bookDetails['link'] = bookURL
            print(bookDetails)
            
            # save to csv
            add_dict_to_csv(bookDetails.values())
            count = count + 1
            # get 10 book
           
            # show 
            print("crawled and saved")
            print()
            if(count==10): 
                print("Stop!!!")
                isBreak = True
                break
        if(isBreak):
            break
except Exception as e:
    print("Error:", e)
    raise e
# Out:
# fetching data... https://www.goodreads.com/book/show/2767052-the-hunger-games
# {'title': 'The Hunger Games', 'author': 'Suzanne Collins', 'language': 'English', 'avg_ratings': '4.33', 'ratings_count': '7,988,812', 'reviews_count': '197,738', 'publisher': 'Scholastic Press', 'publish_year': '2008', 'num_pages': 374, 'page_format': 'Hardcover', 'genres': ['Young Adult', 'Fiction', 'Dystopia', 'Fantasy', 'Science Fiction', 'Romance', 'Adventure', 'Teen', 'Post Apocalyptic', 'Audiobook'], 'link': 'https://www.goodreads.com/book/show/2767052-the-hunger-games'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/2.Harry_Potter_and_the_Order_of_the_Phoenix
# {'title': 'Harry Potter and the Order of the Phoenix', 'author': 'J.K. Rowling', 'language': 'English', 'avg_ratings': '4.50', 'ratings_count': '3,156,328', 'reviews_count': '57,382', 'publisher': 'Scholastic Inc.', 'publish_year': '2004', 'num_pages': 912, 'page_format': 'Paperback', 'genres': ['Fantasy', 'Young Adult', 'Fiction', 'Magic', 'Childrens', 'Audiobook', 'Adventure', 'Middle Grade', 'Classics', 'Science Fiction Fantasy'], 'link': 'https://www.goodreads.com/book/show/2.Harry_Potter_and_the_Order_of_the_Phoenix'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/1885.Pride_and_Prejudice
# {'title': 'Pride and Prejudice', 'author': 'Jane Austen', 'language': 'English', 'avg_ratings': '4.28', 'ratings_count': '3,956,390', 'reviews_count': '101,058', 'publisher': 'Modern Library', 'publish_year': '2000', 'num_pages': 279, 'page_format': 'Paperback', 'genres': ['Classics', 'Fiction', 'Romance', 'Historical Fiction', 'Literature', 'Historical', 'Audiobook', 'Novels', 'Historical Romance', 'Adult'], 'link': 'https://www.goodreads.com/book/show/1885.Pride_and_Prejudice'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird
# {'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'language': 'English', 'avg_ratings': '4.27', 'ratings_count': '5,707,308', 'reviews_count': '110,576', 'publisher': 'Harper Perennial Modern Classics ', 'publish_year': '2006', 'num_pages': 323, 'page_format': 'Paperback', 'genres': ['Classics', 'Fiction', 'Historical Fiction', 'School', 'Literature', 'Young Adult', 'Historical', 'Read For School', 'Novels', 'High School'], 'link': 'https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/19063.The_Book_Thief
# {'title': 'The Book Thief', 'author': 'Markus Zusak', 'language': 'English', 'avg_ratings': '4.39', 'ratings_count': '2,372,023', 'reviews_count': '136,411', 'publisher': 'Alfred A. Knopf', 'publish_year': '2006', 'num_pages': 552, 'page_format': 'Hardcover', 'genres': ['Historical Fiction', 'Fiction', 'Young Adult', 'Historical', 'Classics', 'War', 'World War II', 'Holocaust', 'Books About Books', 'Novels'], 'link': 'https://www.goodreads.com/book/show/19063.The_Book_Thief'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/41865.Twilight
# {'title': 'Twilight', 'author': 'Stephenie Meyer', 'language': 'English', 'avg_ratings': '3.64', 'ratings_count': '6,173,027', 'reviews_count': '122,457', 'publisher': 'Little, Brown and Company', 'publish_year': '2006', 'num_pages': 498, 'page_format': 'Paperback', 'genres': ['Fantasy', 'Young Adult', 'Romance', 'Fiction', 'Vampires', 'Paranormal', 'Paranormal Romance', 'Supernatural', 'Urban Fantasy', 'Teen'], 'link': 'https://www.goodreads.com/book/show/41865.Twilight'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/170448.Animal_Farm
# {'title': 'Animal Farm', 'author': 'George Orwell', 'language': 'English', 'avg_ratings': '3.98', 'ratings_count': '3,587,483', 'reviews_count': '84,765', 'publisher': 'Signet Classics', 'publish_year': '1996', 'num_pages': 128, 'page_format': 'Mass Market Paperback', 'genres': ['Classics', 'Fiction', 'Dystopia', 'Fantasy', 'Politics', 'School', 'Literature', 'Science Fiction', 'Novels', 'Read For School'], 'link': 'https://www.goodreads.com/book/show/170448.Animal_Farm'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/30.J_R_R_Tolkien_4_Book_Boxed_Set
# {'title': 'J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings', 'author': 'J.R.R. Tolkien', 'language': 'English', 'avg_ratings': '4.61', 'ratings_count': '127,607', 'reviews_count': '2,138', 'publisher': 'Ballantine Books', 'publish_year': '2012', 'num_pages': 1728, 'page_format': 'Mass Market Paperback', 'genres': ['Fantasy', 'Fiction', 'Classics', 'Adventure', 'Science Fiction Fantasy', 'Epic Fantasy', 'High Fantasy', 'Young Adult', 'Literature', 'Magic'], 'link': 'https://www.goodreads.com/book/show/30.J_R_R_Tolkien_4_Book_Boxed_Set'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/11127.The_Chronicles_of_Narnia
# {'title': 'The Chronicles of Narnia', 'author': 'C.S. Lewis', 'language': 'English', 'avg_ratings': '4.27', 'ratings_count': '618,360', 'reviews_count': '11,981', 'publisher': 'HarperCollins', 'publish_year': '2014', 'num_pages': 767, 'page_format': 'Paperback', 'genres': ['Fantasy', 'Classics', 'Young Adult', 'Childrens', 'Christian', 'Adventure', 'Middle Grade', 'Science Fiction Fantasy', 'Christian Fiction', 'Magic'], 'link': 'https://www.goodreads.com/book/show/11127.The_Chronicles_of_Narnia'}
# crawled and saved
#
# fetching data... https://www.goodreads.com/book/show/11870085-the-fault-in-our-stars
# {'title': 'The Fault in Our Stars', 'author': 'John Green', 'language': 'English', 'avg_ratings': '4.15', 'ratings_count': '4,777,547', 'reviews_count': '173,207', 'publisher': 'Dutton Books', 'publish_year': '2012', 'num_pages': 313, 'page_format': 'Hardcover', 'genres': ['Young Adult', 'Romance', 'Fiction', 'Contemporary', 'Realistic Fiction', 'Teen', 'Coming Of Age', 'Novels', 'Drama', 'Love'], 'link': 'https://www.goodreads.com/book/show/11870085-the-fault-in-our-stars'}
# crawled and saved
#
# Stop!!!

# %% [markdown]
# ### test crawl a book

# %%
# try:
#     bookURL = 'https://www.goodreads.com/book/show/77203.The_Kite_Runner'
#     # bookURL = 'https://www.goodreads.com/book/show/18626461-messages-from-heaven'
#     soup = get_soup(bookURL)
#     bookDetails = get_book_details_dict(soup)
#     bookDetails['link'] = bookURL
#     add_dict_to_csv(bookDetails.values())
#     print(bookDetails)
# except Exception as e:
#     print("Error:", e)
#     winsound.Beep(440, 2000)  # phát ra âm thanh nếu có lỗi
#     raise e
